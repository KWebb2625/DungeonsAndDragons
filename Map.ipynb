# %% [markdown]
# <a href="https://colab.research.google.com/github/KWebb2625/DungeonsAndDragons/blob/master/Map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pygame

win = pygame.display.set_mode((600, 500))
white = (255, 255, 255)
black = (0, 0, 0)

###############
# MAP LAYOUTS #
###############


class Boundaries(object):
    def __init__(self, start, end):
        self.start = start
        self.end = end

def makemap1():
    mapbounds = pygame.draw.polygon(win, black, 
                [(450, 500), (450, 380), (420, 380), (420, 410), (340, 410),
                 (340, 340), (350, 340), (350, 300), (400, 300), (400, 290),
                 (430, 290), (430, 320), (400, 320), (400, 310), (360, 310),
                 (360, 340), (420, 340), (420, 370), (440, 370), (440, 330),
                 (450, 330), (450, 280), (500, 280), (500, 270), (530, 270),
                 (530, 300), (500, 300), (500, 290), (460, 290), (460, 330),
                 (480, 330), (480, 370), (520, 370), (520, 340), (500, 340),
                 (500, 310), (530, 310), (530, 370), (590, 370), (590, 430),
                 (580, 430), (580, 440), (570, 440), (570, 430), (560, 430),
                 (560, 380), (530, 380), (530, 440), (500, 440), (500, 410),
                 (520, 410), (520, 380), (470, 380), (470, 500), (450, 500)])

    bounds1 = Boundaries((401, 379), (419, 499))
    bounds2 = Boundaries((291, 341), (309, 409))
    bounds3 = Boundaries((301, 301), (310, 341))
    bounds4 = Boundaries((310, 301), (352, 309))
    bounds5 = Boundaries((352, 291), (380, 319))
    bounds6 = Boundaries((391, 331), (429, 371))
    bounds7 = Boundaries((369, 371), (539, 379))
    bounds8 = Boundaries((401, 281), (451, 289))
    bounds9 = Boundaries((401, 289), (409, 331))
    bounds10 = Boundaries((451, 271), (479, 299))
    bounds11 = Boundaries((451, 311), (479, 339))
    bounds12 = Boundaries((451, 411), (479, 439))
    bounds13 = Boundaries((471, 339), (479, 411))
    bounds14 = Boundaries((511, 379), (539, 429))
    bounds15 = Boundaries((521, 429), (529, 439))

    listmapbounds = [bounds1, bounds2, bounds3, bounds4, bounds5, bounds6, bounds7, bounds8,
                     bounds9, bounds10, bounds11, bounds12, bounds13, bounds14, bounds15]
    return mapbounds
    return listmapbounds
   
##########################################

def makemap2():
    pygame.draw.line(win, (255, 255, 255), (400, 500), (400, 450), 3)
    pygame.draw.line(win, (255, 255, 255), (400, 450), (370, 450), 3)
    pygame.draw.line(win, (255, 255, 255), (370, 450), (370, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (370, 470), (350, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (350, 470), (350, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (350, 480), (340, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (340, 480), (340, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (340, 470), (320, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (320, 470), (320, 420), 3)
    pygame.draw.line(win, (255, 255, 255), (320, 420), (340, 420), 3)
    pygame.draw.line(win, (255, 255, 255), (340, 420), (340, 410), 3)
    pygame.draw.line(win, (255, 255, 255), (340, 410), (350, 410), 3)
    pygame.draw.line(win, (255, 255, 255), (350, 410), (350, 420), 3)
    pygame.draw.line(win, (255, 255, 255), (350, 420), (370, 420), 3)
    pygame.draw.line(win, (255, 255, 255), (370, 420), (370, 440), 3)
    pygame.draw.line(win, (255, 255, 255), (370, 440), (440, 440), 3)
    pygame.draw.line(win, (255, 255, 255), (440, 440), (440, 410), 3)
    pygame.draw.line(win, (255, 255, 255), (440, 410), (470, 410), 3)
    pygame.draw.line(win, (255, 255, 255), (470, 410), (470, 440), 3)
    pygame.draw.line(win, (255, 255, 255), (470, 440), (450, 440), 3)
    pygame.draw.line(win, (255, 255, 255), (450, 440), (450, 450), 3)
    pygame.draw.line(win, (255, 255, 255), (450, 450), (420, 450), 3)
    pygame.draw.line(win, (255, 255, 255), (420, 450), (420, 460), 3)
    pygame.draw.line(win, (255, 255, 255), (420, 460), (460, 460), 3)
    pygame.draw.line(win, (255, 255, 255), (460, 460), (460, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (460, 480), (470, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (470, 480), (470, 500), 3)
    pygame.draw.line(win, (255, 255, 255), (470, 500), (440, 500), 3)
    pygame.draw.line(win, (255, 255, 255), (440, 500), (440, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (440, 480), (450, 480), 3)
    pygame.draw.line(win, (255, 255, 255), (450, 480), (450, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (450, 470), (420, 470), 3)
    pygame.draw.line(win, (255, 255, 255), (420, 470), (420, 500), 3)


    listmapbounds = [mapbounds1, mapbounds2, mapbounds3, mapbounds4, 
                     mapbounds5, mapbounds6, mapbounds7, mapbounds8, 
                     mapbounds9, mapbounds10, mapbounds11, mapbounds12, 
                     mapbounds13, mapbounds14, mapbounds15]
    return listmapbounds
